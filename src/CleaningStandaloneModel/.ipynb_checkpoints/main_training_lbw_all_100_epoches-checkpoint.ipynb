# %%
#Imports
from comet_ml import Experiment
experiment = Experiment(api_key="XXXXXXXXXXX", parse_args=False, project_name='XXXXXXXX')
# Out:
# COMET INFO: old comet version (1.0.44) detected. current: 1.0.53 please update your comet lib with command: `pip install --no-cache-dir --upgrade comet_ml`
# COMET WARNING: Failing to collect the installed os packages
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/yikeqicn/segnet/55622919aed24b84b7e3239cc6c99b23

# %%
from os.path import join, basename, dirname
import tensorflow as tf
import shutil
import os
import sys
import argparse

import cv2
import numpy as np
import os
import time

from torch.utils.data import DataLoader, ConcatDataset, random_split#, SequentialSampler #yike: add SequentialSampler
import torch
import torchvision
import torchvision.transforms as transforms
from datasets import ArtPrintNoIntsectLBW,ArtPrintNoIntsectLBW_biameyd_siameyd,ArtPrintNoIntsectLBW_bpr_spr,ArtPrintNoIntsectLBW_biameyd_sprt
from Model_Unet_github import *

home = os.environ['HOME']

# %%
#General Settings
parser = argparse.ArgumentParser()

# system basics
parser.add_argument("-name", default='segnet_unet_lbw_all_combine_100_epoches', type=str, help="name of the log") #debug model_intersect # segnet_no_intersect_1conv_64_channels_30epoch_unet_github
parser.add_argument("-gpu", default='1', type=str, help="gpu numbers")

parser.add_argument("-train", default=True, help="train the NN", action="store_true")

parser.add_argument("-transfer",default=False, help="test the NN", action="store_true")

parser.add_argument("-test",default=False, help="test the NN", action="store_true")

# image and logistic parameters 
parser.add_argument("-image_h", default=32, type=int, help='image height') #('image_h', "360", """ image height """) 32
parser.add_argument("-image_w", default=128, type=int, help='image width')#('image_w', "480", """ image width """)128
#parser.add_argument("-image_h", default=360, type=int, help='image height') 
#parser.add_argument("-image_w", default=480, type=int, help='image width')

parser.add_argument("-image_c", default=1, type=int, help='image channel')#('image_c', "3", """ image channel (RGB) """)
parser.add_argument("-num_class", default=2, type=int, help='total class number')

# training hyperparam
parser.add_argument("-batch_size", default=10, type=int, help='batch_size')
parser.add_argument("-lrInit", default=1e-3, type=int, help='initial lr')
parser.add_argument("-lrDrop1", default=10, type=int, help='step to drop lr by 10 first time') # not sure
parser.add_argument("-lrDrop2", default=1000, type=int, help='step to drop lr by 10 sexond time') # not sure
parser.add_argument('-max_epoch',default=100, type=int,help='max epoch numbers')



# file paths
parser.add_argument('-ckpt_root', default="/root/ckpt", type=str,help= "dir to store ckpt") # log_dir !!!!!
parser.add_argument('-data_root', default="/root/datasets", type=str, help=" root to any data folder ")
parser.add_argument('-urlTranferFrom', default="", type=str, help=" archived model url ")


#args = parser.parse_args()
args = parser.parse_known_args()[0]

name = args.name

experiment.set_name(name)
experiment.log_parameters(vars(args))

os.environ['CUDA_VISIBLE_DEVICES'] = args.gpu

ckptroot = args.ckpt_root
args.ckptpath = join(ckptroot, name)
if args.name=='debug': shutil.rmtree(args.ckptpath, ignore_errors=True)
os.makedirs(args.ckptpath, exist_ok=True)

# %%
def checkArgs():
    if args.test:
        print('The model is set to Testing')
        print("Check point file: %s"%args.ckptpath)
        #print("CamVid testing dir: %s"%FLAGS.test_dir)
    elif args.transfer:
        print('The model is set to transfer learn from ckpt')
        print("Check point file: %s"%args.ckptpath)
        #print("CamVid Image dir: %s"%FLAGS.image_dir)
        #print("CamVid Val dir: %s"%FLAGS.val_dir)
    else:
        print('The model is set to Training')
        print("Max training Iteration: %d"%args.max_epoch)
        print("Initial lr: %f"%args.lrInit)
        print("First Drop Steps: %i"%args.lrDrop1)
        print("Second Drop Steps: %i"%args.lrDrop2)
        print("Data root: %s"%args.data_root)
        print("Check point file: %s"%args.ckptpath)
        #print("CamVid Val dir: %s"%FLAGS.val_dir)

    print("Batch Size: %d"%args.batch_size)

# %%
#main function
def main():    
    checkArgs()
    if args.train:
        transform_train = transforms.Compose([
          transforms.Lambda(lambda img: cv2.resize(img, (args.image_w,args.image_h), interpolation=cv2.INTER_CUBIC)),
          transforms.Lambda(lambda img: np.expand_dims(img,3) ),
          #transforms.Lambda(lambda img: add_artifacts(img,args)),
          #transforms.Lambda(lambda img: cv2.transpose(img))
        ])
        #arprint=ArtPrint(args.data_root, transform=transform_train)
        arhh=ArtPrintNoIntsectLBW_biameyd_siameyd(args.data_root, transform=transform_train)
        arph=ArtPrintNoIntsectLBW(args.data_root, transform=transform_train)
        arpp=ArtPrintNoIntsectLBW_bpr_spr(args.data_root, transform=transform_train)
        arhp=ArtPrintNoIntsectLBW_biameyd_sprt(args.data_root, transform=transform_train)
        concat=ConcatDataset([arhh,arph,arpp,arhp])
        print(len(concat))
        idxTrain = int( len(concat)*0.9)
        trainset, testset = random_split(concat, [idxTrain, len(concat)-idxTrain])
        trainloader = DataLoader(trainset, batch_size=args.batch_size, shuffle=True, drop_last=True,num_workers=4)
        testloader = DataLoader(testset, batch_size=args.batch_size, shuffle=False, drop_last=False,num_workers=2)
        #return trainset, concat
        #weight gen
        # modified here:
        samples_all=[]
        print(trainset.dataset.datasets)
        for ds in trainset.dataset.datasets:
            samples_all+=ds.samples
        #samples_all=trainset.dataset.samples
        print(len(samples_all))
        print(samples_all[0])
        pos_perc=sum(map(lambda x: np.sum(cv2.imread(x[1],cv2.IMREAD_GRAYSCALE)),samples_all))/(args.image_h*args.image_w*len(samples_all))
        neg_perc=1-pos_perc
        weight=np.array([pos_perc,neg_perc]) # just reverse
        print(weight)
        model=Model(args, experiment, loss_weight=weight, mustRestore=False)
        model.training(loader=trainloader, validateloader=testloader)
        
    else:
        pass # for now, leave it pass

# %%
main()
# Out:
# The model is set to Training
# Max training Iteration: 100
# Initial lr: 0.001000
# First Drop Steps: 10
# Second Drop Steps: 1000
# Data root: /root/datasets
# Check point file: /root/ckpt/segnet_unet_lbw_all_combine_100_epoches
# Batch Size: 10
# 823014
# [<datasets.ArtPrintNoIntsectLBW_biameyd_siameyd object at 0x7f8bdbae03c8>, <datasets.ArtPrintNoIntsectLBW object at 0x7f8bdbae0978>, <datasets.ArtPrintNoIntsectLBW_bpr_spr object at 0x7f8b0c050128>, <datasets.ArtPrintNoIntsectLBW_biameyd_sprt object at 0x7f8b05424fd0>]
# 823014
# ('/root/datasets/artifact_images_noins_lbw_biameyd_siameyd/images/d06-067___d06-067-09-00.png', '/root/datasets/artifact_images_noins_lbw_biameyd_siameyd/labels/d06-067___d06-067-09-00.png', 'd06-067-09-00')
# [0.10126392 0.89873608]
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# GGG
# [None, 32, 128, 1]
# WARNING:tensorflow:From /root/SegNet/Model_Unet_github.py:49: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /root/SegNet/Model_Unet_github.py:49: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/nn_ops.py:3042: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/nn_ops.py:3042: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# 0 conv1: (?, ?, ?, 32)
# 0 conv2: (?, ?, ?, 32)
# 1 conv1: (?, ?, ?, 64)
# 1 conv2: (?, ?, ?, 64)
# 2 conv1: (?, ?, ?, 128)
# 2 conv2: (?, ?, ?, 128)
# 1 h_deconv: (?, ?, ?, 64)
# 1 h_deconv_concat: (?, ?, ?, ?)
# 1 h_conv1_post_deconv: (?, ?, ?, 64)
# 1 h_conv2_post_deconv: (?, ?, ?, 64)
# 0 h_deconv: (?, ?, ?, 32)
# 0 h_deconv_concat: (?, ?, ?, ?)
# 0 h_conv1_post_deconv: (?, ?, ?, 32)
# 0 h_conv2_post_deconv: (?, ?, ?, 32)
# 0 outmap: (?, ?, ?, 2)
# (?, ?, ?, 2)
# loss: ()
# INFO:tensorflow:Summary name loss/cross_entropy (raw) is illegal; using loss/cross_entropy__raw_ instead.
# INFO:tensorflow:Summary name loss/cross_entropy (raw) is illegal; using loss/cross_entropy__raw_ instead.
# INFO:tensorflow:Summary name loss/total_loss (raw) is illegal; using loss/total_loss__raw_ instead.
# INFO:tensorflow:Summary name loss/total_loss (raw) is illegal; using loss/total_loss__raw_ instead.
# COMET ERROR: Failed to extract parameters from Estimator.init()
# toto_loss_shape: Tensor("loss/total_loss:0", shape=(), dtype=float32)
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_ops.py:3197: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_ops.py:3197: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Python: 3.5.2 (default, Nov 12 2018, 13:43:14)
# [GCC 5.4.0 20160609]
# Tensorflow: 1.12.0-rc0
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1557: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1557: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /root/ckpt/segnet_unet_lbw_all_combine_100_epoches/model-38
# INFO:tensorflow:Restoring parameters from /root/ckpt/segnet_unet_lbw_all_combine_100_epoches/model-38
# Init with stored values from /root/ckpt/segnet_unet_lbw_all_combine_100_epoches/model-38
# Epoch: 1  Training...
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   import sys
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   import sys
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   import sys
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   import sys
# TRAIN: Batch: 0.0 Loss: 0.018470937
# accuracy = 0.956559
# mean IU  = 0.810851
#     class # 0 capture rate = 0.955646
#     class # 1 capture rate = 0.965674
# TRAIN: Batch: 0.001350056027325134 Loss: 0.018784184
# accuracy = 0.947402
# mean IU  = 0.813843
#     class # 0 capture rate = 0.942510
#     class # 1 capture rate = 0.984183
# TRAIN: Batch: 0.002700112054650268 Loss: 0.013376174
# accuracy = 0.962416
# mean IU  = 0.799446
#     class # 0 capture rate = 0.961824
#     class # 1 capture rate = 0.970452
# TRAIN: Batch: 0.004050168081975402 Loss: 0.015904475
# accuracy = 0.959126
# mean IU  = 0.829760
#     class # 0 capture rate = 0.957945
#     class # 1 capture rate = 0.969675
# TRAIN: Batch: 0.005400224109300536 Loss: 0.022122342
# accuracy = 0.942960
# mean IU  = 0.800405
#     class # 0 capture rate = 0.939190
#     class # 1 capture rate = 0.971524
# TRAIN: Batch: 0.00675028013662567 Loss: 0.013224324
# accuracy = 0.963391
# mean IU  = 0.827323
#     class # 0 capture rate = 0.962939
#     class # 1 capture rate = 0.968191
# TRAIN: Batch: 0.008100336163950804 Loss: 0.013803574
# accuracy = 0.963044
# mean IU  = 0.856425
#     class # 0 capture rate = 0.960160
#     class # 1 capture rate = 0.985173
# TRAIN: Batch: 0.009450392191275938 Loss: 0.0138852
# accuracy = 0.966323
# mean IU  = 0.851620
#     class # 0 capture rate = 0.965743
#     class # 1 capture rate = 0.971605
# TRAIN: Batch: 0.010800448218601072 Loss: 0.0151113365
# accuracy = 0.966271
# mean IU  = 0.841836
#     class # 0 capture rate = 0.965330
#     class # 1 capture rate = 0.975890
# TRAIN: Batch: 0.012150504245926206 Loss: 0.017095944
# accuracy = 0.958722
# mean IU  = 0.830753
#     class # 0 capture rate = 0.957524
#     class # 1 capture rate = 0.969158
# TRAIN: Batch: 0.01350056027325134 Loss: 0.017402444
# accuracy = 0.955818
# mean IU  = 0.805849
#     class # 0 capture rate = 0.954145
#     class # 1 capture rate = 0.973123
# TRAIN: Batch: 0.014850616300576474 Loss: 0.017917901
# accuracy = 0.951588
# mean IU  = 0.789369
#     class # 0 capture rate = 0.949255
#     class # 1 capture rate = 0.976711
# TRAIN: Batch: 0.016200672327901608 Loss: 0.025599768
# accuracy = 0.936077
# mean IU  = 0.782588
#     class # 0 capture rate = 0.932046
#     class # 1 capture rate = 0.966765
# TRAIN: Batch: 0.017550728355226742 Loss: 0.012170145
# accuracy = 0.967668
# mean IU  = 0.873964
#     class # 0 capture rate = 0.964046
#     class # 1 capture rate = 0.994637
# TRAIN: Batch: 0.018900784382551876 Loss: 0.012554822
# accuracy = 0.965932
# mean IU  = 0.838422
#     class # 0 capture rate = 0.964282
#     class # 1 capture rate = 0.983347
# TRAIN: Batch: 0.02025084040987701 Loss: 0.0142395515
# accuracy = 0.961097
# mean IU  = 0.804093
#     class # 0 capture rate = 0.959910
#     class # 1 capture rate = 0.975931
# TRAIN: Batch: 0.021600896437202144 Loss: 0.019585036
# accuracy = 0.953158
# mean IU  = 0.818582
#     class # 0 capture rate = 0.951195
#     class # 1 capture rate = 0.969490
# TRAIN: Batch: 0.022950952464527278 Loss: 0.015198116
# accuracy = 0.963609
# mean IU  = 0.866988
#     class # 0 capture rate = 0.961354
#     class # 1 capture rate = 0.978901
# TRAIN: Batch: 0.024301008491852412 Loss: 0.016158996
# accuracy = 0.954359
# mean IU  = 0.819548
#     class # 0 capture rate = 0.951399
#     class # 1 capture rate = 0.979967
# TRAIN: Batch: 0.025651064519177546 Loss: 0.021190748
# accuracy = 0.950944
# mean IU  = 0.826829
#     class # 0 capture rate = 0.947635
#     class # 1 capture rate = 0.974563
# TRAIN: Batch: 0.02700112054650268 Loss: 0.017421106
# accuracy = 0.960704
# mean IU  = 0.825453
#     class # 0 capture rate = 0.959715
#     class # 1 capture rate = 0.970487
# TRAIN: Batch: 0.028351176573827814 Loss: 0.015645344
# accuracy = 0.964589
# mean IU  = 0.844369
#     class # 0 capture rate = 0.963432
#     class # 1 capture rate = 0.975352
# TRAIN: Batch: 0.029701232601152948 Loss: 0.012323226
# accuracy = 0.969642
# mean IU  = 0.848990
#     class # 0 capture rate = 0.968949
#     class # 1 capture rate = 0.977154
# TRAIN: Batch: 0.031051288628478082 Loss: 0.013694489
# accuracy = 0.963899
# mean IU  = 0.828788
#     class # 0 capture rate = 0.962734
#     class # 1 capture rate = 0.976444
# TRAIN: Batch: 0.032401344655803216 Loss: 0.015349145
# accuracy = 0.964667
# mean IU  = 0.814701
#     class # 0 capture rate = 0.964937
#     class # 1 capture rate = 0.961271
# TRAIN: Batch: 0.033751400683128346 Loss: 0.018005542
# accuracy = 0.958047
# mean IU  = 0.815445
#     class # 0 capture rate = 0.955950
#     class # 1 capture rate = 0.979320
# TRAIN: Batch: 0.035101456710453484 Loss: 0.016505372
# accuracy = 0.961189
# mean IU  = 0.828114
#     class # 0 capture rate = 0.960337
#     class # 1 capture rate = 0.969506
# TRAIN: Batch: 0.036451512737778614 Loss: 0.015246761
# accuracy = 0.959266
# mean IU  = 0.846521
#     class # 0 capture rate = 0.956038
#     class # 1 capture rate = 0.983555
# TRAIN: Batch: 0.03780156876510375 Loss: 0.018037215
# accuracy = 0.956162
# mean IU  = 0.843155
#     class # 0 capture rate = 0.953365
#     class # 1 capture rate = 0.975662
# TRAIN: Batch: 0.03915162479242888 Loss: 0.020950923
# accuracy = 0.946921
# mean IU  = 0.793124
#     class # 0 capture rate = 0.943833
#     class # 1 capture rate = 0.975056
# TRAIN: Batch: 0.04050168081975402 Loss: 0.014171672
# accuracy = 0.964542
# mean IU  = 0.859193
#     class # 0 capture rate = 0.962511
#     class # 1 capture rate = 0.980413
# TRAIN: Batch: 0.04185173684707915 Loss: 0.017887888
# accuracy = 0.955160
# mean IU  = 0.813610
#     class # 0 capture rate = 0.952853
#     class # 1 capture rate = 0.976868
# TRAIN: Batch: 0.04320179287440429 Loss: 0.017360955
# accuracy = 0.953061
# mean IU  = 0.825355
#     class # 0 capture rate = 0.948768
#     class # 1 capture rate = 0.986802
# TRAIN: Batch: 0.04455184890172942 Loss: 0.011474907
# accuracy = 0.969058
# mean IU  = 0.850464
#     class # 0 capture rate = 0.967138
#     class # 1 capture rate = 0.989290
# TRAIN: Batch: 0.045901904929054556 Loss: 0.01628688
# accuracy = 0.963393
# mean IU  = 0.849383
#     class # 0 capture rate = 0.961898
#     class # 1 capture rate = 0.975934
# TRAIN: Batch: 0.047251960956379686 Loss: 0.016980521
# accuracy = 0.953429
# mean IU  = 0.816439
#     class # 0 capture rate = 0.950048
#     class # 1 capture rate = 0.982910
# TRAIN: Batch: 0.048602016983704824 Loss: 0.015653357
# accuracy = 0.960784
# mean IU  = 0.832202
#     class # 0 capture rate = 0.958972
#     class # 1 capture rate = 0.977627
# TRAIN: Batch: 0.049952073011029954 Loss: 0.014385557
# accuracy = 0.961688
# mean IU  = 0.815025
#     class # 0 capture rate = 0.960492
#     class # 1 capture rate = 0.975380
# TRAIN: Batch: 0.05130212903835509 Loss: 0.019056575
# accuracy = 0.954422
# mean IU  = 0.825499
#     class # 0 capture rate = 0.951751
#     class # 1 capture rate = 0.976027
# TRAIN: Batch: 0.05265218506568022 Loss: 0.0142268445
# accuracy = 0.959747
# mean IU  = 0.840745
#     class # 0 capture rate = 0.956103
#     class # 1 capture rate = 0.989828
# TRAIN: Batch: 0.05400224109300536 Loss: 0.017127177
# accuracy = 0.960424
# mean IU  = 0.841200
#     class # 0 capture rate = 0.958992
#     class # 1 capture rate = 0.972228
# TRAIN: Batch: 0.05535229712033049 Loss: 0.01803721
# accuracy = 0.960873
# mean IU  = 0.830076
#     class # 0 capture rate = 0.960131
#     class # 1 capture rate = 0.967882
# TRAIN: Batch: 0.05670235314765563 Loss: 0.019805472
# accuracy = 0.954642
# mean IU  = 0.815595
#     class # 0 capture rate = 0.952862
#     class # 1 capture rate = 0.970674
# TRAIN: Batch: 0.05805240917498076 Loss: 0.017596496
# accuracy = 0.956243
# mean IU  = 0.816628
#     class # 0 capture rate = 0.954138
#     class # 1 capture rate = 0.976075
# TRAIN: Batch: 0.059402465202305896 Loss: 0.015585542
# accuracy = 0.959921
# mean IU  = 0.825908
#     class # 0 capture rate = 0.958063
#     class # 1 capture rate = 0.977870
# TRAIN: Batch: 0.060752521229631026 Loss: 0.018869841
# accuracy = 0.952254
# mean IU  = 0.811539
#     class # 0 capture rate = 0.949364
#     class # 1 capture rate = 0.977719
# TRAIN: Batch: 0.062102577256956164 Loss: 0.016864423
# accuracy = 0.959610
# mean IU  = 0.822967
#     class # 0 capture rate = 0.958675
#     class # 1 capture rate = 0.968734
# TRAIN: Batch: 0.0634526332842813 Loss: 0.019189874
# accuracy = 0.952744
# mean IU  = 0.817135
#     class # 0 capture rate = 0.950409
#     class # 1 capture rate = 0.972299
# TRAIN: Batch: 0.06480268931160643 Loss: 0.016783765
# accuracy = 0.959041
# mean IU  = 0.829398
#     class # 0 capture rate = 0.957414
#     class # 1 capture rate = 0.973659
# TRAIN: Batch: 0.06615274533893156 Loss: 0.01768933
# accuracy = 0.951969
# mean IU  = 0.802584
#     class # 0 capture rate = 0.949299
#     class # 1 capture rate = 0.977537
# TRAIN: Batch: 0.06750280136625669 Loss: 0.015047455
# accuracy = 0.968639
# mean IU  = 0.854480
#     class # 0 capture rate = 0.969045
#     class # 1 capture rate = 0.964739
# TRAIN: Batch: 0.06885285739358184 Loss: 0.013517794
# accuracy = 0.968745
# mean IU  = 0.867984
#     class # 0 capture rate = 0.966972
#     class # 1 capture rate = 0.983558
# TRAIN: Batch: 0.07020291342090697 Loss: 0.018887943
# accuracy = 0.953198
# mean IU  = 0.821478
#     class # 0 capture rate = 0.950357
#     class # 1 capture rate = 0.976323
# TRAIN: Batch: 0.0715529694482321 Loss: 0.0127984015
# accuracy = 0.966574
# mean IU  = 0.860353
#     class # 0 capture rate = 0.964584
#     class # 1 capture rate = 0.983265
# TRAIN: Batch: 0.07290302547555723 Loss: 0.01351026
# accuracy = 0.964617
# mean IU  = 0.848357
#     class # 0 capture rate = 0.962388
#     class # 1 capture rate = 0.984642
# TRAIN: Batch: 0.07425308150288237 Loss: 0.016722176
# accuracy = 0.956720
# mean IU  = 0.808902
#     class # 0 capture rate = 0.955023
#     class # 1 capture rate = 0.974260
# TRAIN: Batch: 0.0756031375302075 Loss: 0.017291974
# accuracy = 0.956531
# mean IU  = 0.832222
#     class # 0 capture rate = 0.954268
#     class # 1 capture rate = 0.974675
# TRAIN: Batch: 0.07695319355753263 Loss: 0.015859628
# accuracy = 0.961929
# mean IU  = 0.832517
#     class # 0 capture rate = 0.960844
#     class # 1 capture rate = 0.972337
# TRAIN: Batch: 0.07830324958485776 Loss: 0.016364003
# accuracy = 0.958481
# mean IU  = 0.819428
#     class # 0 capture rate = 0.956502
#     class # 1 capture rate = 0.977990
# TRAIN: Batch: 0.07965330561218291 Loss: 0.019685036
# accuracy = 0.957353
# mean IU  = 0.822976
#     class # 0 capture rate = 0.955752
#     class # 1 capture rate = 0.971907
# TRAIN: Batch: 0.08100336163950804 Loss: 0.017260045
# accuracy = 0.956030
# mean IU  = 0.847034
#     class # 0 capture rate = 0.951568
#     class # 1 capture rate = 0.985902
# TRAIN: Batch: 0.08235341766683317 Loss: 0.014960999
# accuracy = 0.959581
# mean IU  = 0.830866
#     class # 0 capture rate = 0.957556
#     class # 1 capture rate = 0.977909
# TRAIN: Batch: 0.0837034736941583 Loss: 0.01600445
# accuracy = 0.959285
# mean IU  = 0.821407
#     class # 0 capture rate = 0.958080
#     class # 1 capture rate = 0.971141
# TRAIN: Batch: 0.08505352972148345 Loss: 0.016832847
# accuracy = 0.962581
# mean IU  = 0.849333
#     class # 0 capture rate = 0.960786
#     class # 1 capture rate = 0.977207
# TRAIN: Batch: 0.08640358574880858 Loss: 0.014379662
# accuracy = 0.963131
# mean IU  = 0.840922
#     class # 0 capture rate = 0.961265
#     class # 1 capture rate = 0.980314
# TRAIN: Batch: 0.0877536417761337 Loss: 0.01809818
# accuracy = 0.956145
# mean IU  = 0.817131
#     class # 0 capture rate = 0.955026
#     class # 1 capture rate = 0.966483
# TRAIN: Batch: 0.08910369780345884 Loss: 0.016638115
# accuracy = 0.952279
# mean IU  = 0.829747
#     class # 0 capture rate = 0.947517
#     class # 1 capture rate = 0.987029
# TRAIN: Batch: 0.09045375383078398 Loss: 0.013551851
# accuracy = 0.956086
# mean IU  = 0.818549
#     class # 0 capture rate = 0.953262
#     class # 1 capture rate = 0.982219
# TRAIN: Batch: 0.09180380985810911 Loss: 0.011781672
# accuracy = 0.967496
# mean IU  = 0.852185
#     class # 0 capture rate = 0.965765
#     class # 1 capture rate = 0.984168
# TRAIN: Batch: 0.09315386588543424 Loss: 0.017980868
# accuracy = 0.955656
# mean IU  = 0.779242
#     class # 0 capture rate = 0.955691
#     class # 1 capture rate = 0.955214
# TRAIN: Batch: 0.09450392191275937 Loss: 0.015277201
# accuracy = 0.960155
# mean IU  = 0.820515
#     class # 0 capture rate = 0.958227
#     class # 1 capture rate = 0.980072
# TRAIN: Batch: 0.09585397794008452 Loss: 0.021912685
# accuracy = 0.952794
# mean IU  = 0.827753
#     class # 0 capture rate = 0.950151
#     class # 1 capture rate = 0.972515
# TRAIN: Batch: 0.09720403396740965 Loss: 0.016974015
# accuracy = 0.961223
# mean IU  = 0.820578
#     class # 0 capture rate = 0.960983
#     class # 1 capture rate = 0.963744
# TRAIN: Batch: 0.09855408999473478 Loss: 0.016682178
# accuracy = 0.954451
# mean IU  = 0.805461
#     class # 0 capture rate = 0.951390
#     class # 1 capture rate = 0.985362
# TRAIN: Batch: 0.09990414602205991 Loss: 0.011980103
# accuracy = 0.971549
# mean IU  = 0.881862
#     class # 0 capture rate = 0.969761
#     class # 1 capture rate = 0.985665
# TRAIN: Batch: 0.10125420204938505 Loss: 0.014278635
# accuracy = 0.961902
# mean IU  = 0.828439
#     class # 0 capture rate = 0.959650
#     class # 1 capture rate = 0.984754
# TRAIN: Batch: 0.10260425807671018 Loss: 0.018801404
# accuracy = 0.956589
# mean IU  = 0.831295
#     class # 0 capture rate = 0.953819
#     class # 1 capture rate = 0.979190
# TRAIN: Batch: 0.10395431410403531 Loss: 0.012830826
# accuracy = 0.964956
# mean IU  = 0.832675
#     class # 0 capture rate = 0.963625
#     class # 1 capture rate = 0.979298
# TRAIN: Batch: 0.10530437013136044 Loss: 0.014367491
# accuracy = 0.964394
# mean IU  = 0.867809
#     class # 0 capture rate = 0.961573
#     class # 1 capture rate = 0.984047
# TRAIN: Batch: 0.10665442615868559 Loss: 0.017865693
# accuracy = 0.959026
# mean IU  = 0.844729
#     class # 0 capture rate = 0.957260
#     class # 1 capture rate = 0.972315
# TRAIN: Batch: 0.10800448218601072 Loss: 0.016198974
# accuracy = 0.958456
# mean IU  = 0.828557
#     class # 0 capture rate = 0.956694
#     class # 1 capture rate = 0.974136
# TRAIN: Batch: 0.10935453821333585 Loss: 0.023594767
# accuracy = 0.935678
# mean IU  = 0.790999
#     class # 0 capture rate = 0.930133
#     class # 1 capture rate = 0.974314
# TRAIN: Batch: 0.11070459424066098 Loss: 0.017119026
# accuracy = 0.952904
# mean IU  = 0.830840
#     class # 0 capture rate = 0.948720
#     class # 1 capture rate = 0.983537
# TRAIN: Batch: 0.11205465026798613 Loss: 0.017840996
# accuracy = 0.961276
# mean IU  = 0.825317
#     class # 0 capture rate = 0.961117
#     class # 1 capture rate = 0.962873
# TRAIN: Batch: 0.11340470629531126 Loss: 0.014433717
# accuracy = 0.962076
# mean IU  = 0.804010
#     class # 0 capture rate = 0.961896
#     class # 1 capture rate = 0.964370
# TRAIN: Batch: 0.11475476232263639 Loss: 0.014257917
# accuracy = 0.965048
# mean IU  = 0.831956
#     class # 0 capture rate = 0.964170
#     class # 1 capture rate = 0.974559
# TRAIN: Batch: 0.11610481834996152 Loss: 0.01767956
# accuracy = 0.951647
# mean IU  = 0.804883
#     class # 0 capture rate = 0.948350
#     class # 1 capture rate = 0.982363
# TRAIN: Batch: 0.11745487437728666 Loss: 0.011561007
# accuracy = 0.968835
# mean IU  = 0.875375
#     class # 0 capture rate = 0.966648
#     class # 1 capture rate = 0.985486
# TRAIN: Batch: 0.11880493040461179 Loss: 0.021362346
# accuracy = 0.948713
# mean IU  = 0.821650
#     class # 0 capture rate = 0.944749
#     class # 1 capture rate = 0.976855
# TRAIN: Batch: 0.12015498643193692 Loss: 0.015928034
# accuracy = 0.956290
# mean IU  = 0.839829
#     class # 0 capture rate = 0.951856
#     class # 1 capture rate = 0.989124
# TRAIN: Batch: 0.12150504245926205 Loss: 0.012789702
# accuracy = 0.964123
# mean IU  = 0.844970
#     class # 0 capture rate = 0.961394
#     class # 1 capture rate = 0.989271
# TRAIN: Batch: 0.1228550984865872 Loss: 0.015315672
# accuracy = 0.958776
# mean IU  = 0.830236
#     class # 0 capture rate = 0.956419
#     class # 1 capture rate = 0.979720
# TRAIN: Batch: 0.12420515451391233 Loss: 0.022872245
# accuracy = 0.944929
# mean IU  = 0.797276
#     class # 0 capture rate = 0.941678
#     class # 1 capture rate = 0.971751
# TRAIN: Batch: 0.12555521054123747 Loss: 0.020500198
# accuracy = 0.948496
# mean IU  = 0.798543
#     class # 0 capture rate = 0.946265
#     class # 1 capture rate = 0.968439
# TRAIN: Batch: 0.1269052665685626 Loss: 0.013792047
# accuracy = 0.963925
# mean IU  = 0.844811
#     class # 0 capture rate = 0.961910
#     class # 1 capture rate = 0.982253
# TRAIN: Batch: 0.12825532259588773 Loss: 0.015566546
# accuracy = 0.964439
# mean IU  = 0.869844
#     class # 0 capture rate = 0.961607
#     class # 1 capture rate = 0.983650
# TRAIN: Batch: 0.12960537862321286 Loss: 0.01120246
# accuracy = 0.972916
# mean IU  = 0.872590
#     class # 0 capture rate = 0.971411
#     class # 1 capture rate = 0.987339
# TRAIN: Batch: 0.130955434650538 Loss: 0.015090649
# accuracy = 0.964800
# mean IU  = 0.836142
#     class # 0 capture rate = 0.963863
#     class # 1 capture rate = 0.974415
# TRAIN: Batch: 0.13230549067786312 Loss: 0.019782396
# accuracy = 0.940921
# mean IU  = 0.789957
#     class # 0 capture rate = 0.936186
#     class # 1 capture rate = 0.979162
# TRAIN: Batch: 0.13365554670518826 Loss: 0.017027196
# accuracy = 0.954683
# mean IU  = 0.793912
#     class # 0 capture rate = 0.953094
#     class # 1 capture rate = 0.972521
# TRAIN: Batch: 0.13500560273251339 Loss: 0.019874495
# accuracy = 0.952623
# mean IU  = 0.816122
#     class # 0 capture rate = 0.950025
#     class # 1 capture rate = 0.974596
# TRAIN: Batch: 0.13635565875983854 Loss: 0.016017826
# accuracy = 0.955761
# mean IU  = 0.801717
#     class # 0 capture rate = 0.953827
#     class # 1 capture rate = 0.976650
# TRAIN: Batch: 0.13770571478716367 Loss: 0.014884469
# accuracy = 0.958067
# mean IU  = 0.822564
#     class # 0 capture rate = 0.955238
#     class # 1 capture rate = 0.984895
# TRAIN: Batch: 0.1390557708144888 Loss: 0.015309569
# accuracy = 0.963106
# mean IU  = 0.830783
#     class # 0 capture rate = 0.962064
#     class # 1 capture rate = 0.973735
# TRAIN: Batch: 0.14040582684181394 Loss: 0.01902757
# accuracy = 0.947081
# mean IU  = 0.777704
#     class # 0 capture rate = 0.945587
#     class # 1 capture rate = 0.962724
# TRAIN: Batch: 0.14175588286913907 Loss: 0.011182876
# accuracy = 0.967424
# mean IU  = 0.821094
#     class # 0 capture rate = 0.966276
#     class # 1 capture rate = 0.982789
# TRAIN: Batch: 0.1431059388964642 Loss: 0.017010424
# accuracy = 0.960485
# mean IU  = 0.846529
#     class # 0 capture rate = 0.958261
#     class # 1 capture rate = 0.977845
# TRAIN: Batch: 0.14445599492378933 Loss: 0.01747261
# accuracy = 0.958776
# mean IU  = 0.832009
#     class # 0 capture rate = 0.957220
#     class # 1 capture rate = 0.972222
# TRAIN: Batch: 0.14580605095111446 Loss: 0.015329218
# accuracy = 0.962744
# mean IU  = 0.845307
#     class # 0 capture rate = 0.960401
#     class # 1 capture rate = 0.983027
# TRAIN: Batch: 0.14715610697843962 Loss: 0.016263103
# accuracy = 0.961703
# mean IU  = 0.839052
#     class # 0 capture rate = 0.959430
#     class # 1 capture rate = 0.982030
# TRAIN: Batch: 0.14850616300576475 Loss: 0.01564649
# accuracy = 0.957019
# mean IU  = 0.806118
#     class # 0 capture rate = 0.954674
#     class # 1 capture rate = 0.982390
# TRAIN: Batch: 0.14985621903308988 Loss: 0.014263844
# accuracy = 0.968135
# mean IU  = 0.828731
#     class # 0 capture rate = 0.968278
#     class # 1 capture rate = 0.966348
# TRAIN: Batch: 0.151206275060415 Loss: 0.0190535
# accuracy = 0.957301
# mean IU  = 0.829390
#     class # 0 capture rate = 0.955118
#     class # 1 capture rate = 0.975864
# TRAIN: Batch: 0.15255633108774014 Loss: 0.0168274
# accuracy = 0.951377
# mean IU  = 0.778043
#     class # 0 capture rate = 0.949506
#     class # 1 capture rate = 0.973593
# TRAIN: Batch: 0.15390638711506527 Loss: 0.015621508
# accuracy = 0.957978
# mean IU  = 0.830981
#     class # 0 capture rate = 0.954984
#     class # 1 capture rate = 0.983784
# TRAIN: Batch: 0.1552564431423904 Loss: 0.02404604
# accuracy = 0.937556
# mean IU  = 0.818439
#     class # 0 capture rate = 0.929680
#     class # 1 capture rate = 0.980016
# TRAIN: Batch: 0.15660649916971553 Loss: 0.018546473
# accuracy = 0.947421
# mean IU  = 0.800843
#     class # 0 capture rate = 0.943670
#     class # 1 capture rate = 0.979630
# TRAIN: Batch: 0.1579565551970407 Loss: 0.018984178
# accuracy = 0.951532
# mean IU  = 0.802041
#     class # 0 capture rate = 0.949217
#     class # 1 capture rate = 0.973436
# TRAIN: Batch: 0.15930661122436582 Loss: 0.016252413
# accuracy = 0.958192
# mean IU  = 0.805429
#     class # 0 capture rate = 0.956698
#     class # 1 capture rate = 0.974948
# TRAIN: Batch: 0.16065666725169095 Loss: 0.021731537
# accuracy = 0.941843
# mean IU  = 0.779822
#     class # 0 capture rate = 0.938448
#     class # 1 capture rate = 0.972667
# TRAIN: Batch: 0.16200672327901608 Loss: 0.022801617
# accuracy = 0.940633
# mean IU  = 0.792009
#     class # 0 capture rate = 0.936283
#     class # 1 capture rate = 0.974613
# TRAIN: Batch: 0.1633567793063412 Loss: 0.012125353
# accuracy = 0.967272
# mean IU  = 0.850330
#     class # 0 capture rate = 0.965634
#     class # 1 capture rate = 0.983215
# TRAIN: Batch: 0.16470683533366634 Loss: 0.017711129
# accuracy = 0.963424
# mean IU  = 0.824672
#     class # 0 capture rate = 0.962575
#     class # 1 capture rate = 0.972759
# TRAIN: Batch: 0.16605689136099147 Loss: 0.020101273
# accuracy = 0.947530
# mean IU  = 0.820346
#     class # 0 capture rate = 0.943527
#     class # 1 capture rate = 0.975345
# TRAIN: Batch: 0.1674069473883166 Loss: 0.017267052
# accuracy = 0.959991
# mean IU  = 0.835448
#     class # 0 capture rate = 0.957859
#     class # 1 capture rate = 0.978607
# TRAIN: Batch: 0.16875700341564176 Loss: 0.01283403
# accuracy = 0.969623
# mean IU  = 0.843093
#     class # 0 capture rate = 0.969294
#     class # 1 capture rate = 0.973411
# TRAIN: Batch: 0.1701070594429669 Loss: 0.013652086
# accuracy = 0.962365
# mean IU  = 0.828690
#     class # 0 capture rate = 0.960799
#     class # 1 capture rate = 0.978362
# TRAIN: Batch: 0.17145711547029202 Loss: 0.019066876
# accuracy = 0.950856
# mean IU  = 0.817541
#     class # 0 capture rate = 0.947619
#     class # 1 capture rate = 0.976481
# TRAIN: Batch: 0.17280717149761715 Loss: 0.015819382
# accuracy = 0.954764
# mean IU  = 0.788719
#     class # 0 capture rate = 0.953774
#     class # 1 capture rate = 0.966387
# TRAIN: Batch: 0.17415722752494228 Loss: 0.014632359
# accuracy = 0.961248
# mean IU  = 0.828642
#     class # 0 capture rate = 0.958865
#     class # 1 capture rate = 0.984832
# TRAIN: Batch: 0.1755072835522674 Loss: 0.018119365
# accuracy = 0.957280
# mean IU  = 0.810814
#     class # 0 capture rate = 0.957067
#     class # 1 capture rate = 0.959445
# TRAIN: Batch: 0.17685733957959254 Loss: 0.012665419
# accuracy = 0.965251
# mean IU  = 0.850740
#     class # 0 capture rate = 0.962845
#     class # 1 capture rate = 0.986845
# TRAIN: Batch: 0.17820739560691767 Loss: 0.016453484
# accuracy = 0.961699
# mean IU  = 0.838562
#     class # 0 capture rate = 0.960099
#     class # 1 capture rate = 0.975988
# TRAIN: Batch: 0.17955745163424283 Loss: 0.014086795
# accuracy = 0.958302
# mean IU  = 0.805784
#     class # 0 capture rate = 0.956029
#     class # 1 capture rate = 0.984041
# TRAIN: Batch: 0.18090750766156796 Loss: 0.016649177
# accuracy = 0.959755
# mean IU  = 0.832409
#     class # 0 capture rate = 0.958510
#     class # 1 capture rate = 0.970808
# TRAIN: Batch: 0.1822575636888931 Loss: 0.017736193
# accuracy = 0.950430
# mean IU  = 0.787782
#     class # 0 capture rate = 0.948751
#     class # 1 capture rate = 0.968031
# TRAIN: Batch: 0.18360761971621822 Loss: 0.017055133
# accuracy = 0.955015
# mean IU  = 0.829486
#     class # 0 capture rate = 0.951237
#     class # 1 capture rate = 0.985111
# TRAIN: Batch: 0.18495767574354335 Loss: 0.018863793
# accuracy = 0.954285
# mean IU  = 0.813906
#     class # 0 capture rate = 0.952262
#     class # 1 capture rate = 0.972660
# TRAIN: Batch: 0.18630773177086848 Loss: 0.017631749
# accuracy = 0.958995
# mean IU  = 0.826388
#     class # 0 capture rate = 0.957697
#     class # 1 capture rate = 0.970985
# TRAIN: Batch: 0.18765778779819361 Loss: 0.014972225
# accuracy = 0.962192
# mean IU  = 0.824586
#     class # 0 capture rate = 0.960555
#     class # 1 capture rate = 0.979574
# TRAIN: Batch: 0.18900784382551875 Loss: 0.018709624
# accuracy = 0.957398
# mean IU  = 0.816060
#     class # 0 capture rate = 0.956596
#     class # 1 capture rate = 0.965192
# TRAIN: Batch: 0.1903578998528439 Loss: 0.016629238
# accuracy = 0.958686
# mean IU  = 0.798979
#     class # 0 capture rate = 0.958405
#     class # 1 capture rate = 0.962049
# TRAIN: Batch: 0.19170795588016903 Loss: 0.015834326
# accuracy = 0.960681
# mean IU  = 0.839516
#     class # 0 capture rate = 0.958300
#     class # 1 capture rate = 0.981075
# TRAIN: Batch: 0.19305801190749416 Loss: 0.016023938
# accuracy = 0.959308
# mean IU  = 0.835347
#     class # 0 capture rate = 0.957052
#     class # 1 capture rate = 0.978570
# TRAIN: Batch: 0.1944080679348193 Loss: 0.019731402
# accuracy = 0.948432
# mean IU  = 0.805800
#     class # 0 capture rate = 0.945107
#     class # 1 capture rate = 0.976223
# TRAIN: Batch: 0.19575812396214443 Loss: 0.017168712
# accuracy = 0.953737
# mean IU  = 0.832020
#     class # 0 capture rate = 0.950216
#     class # 1 capture rate = 0.979730
# TRAIN: Batch: 0.19710817998946956 Loss: 0.016306113
# accuracy = 0.963830
# mean IU  = 0.827675
#     class # 0 capture rate = 0.963585
#     class # 1 capture rate = 0.966456
# TRAIN: Batch: 0.1984582360167947 Loss: 0.017096724
# accuracy = 0.962369
# mean IU  = 0.840995
#     class # 0 capture rate = 0.960935
#     class # 1 capture rate = 0.975121
# TRAIN: Batch: 0.19980829204411982 Loss: 0.013502573
# accuracy = 0.966228
# mean IU  = 0.846048
#     class # 0 capture rate = 0.964896
#     class # 1 capture rate = 0.979232
# TRAIN: Batch: 0.20115834807144498 Loss: 0.020717481
# accuracy = 0.954964
# mean IU  = 0.823416
#     class # 0 capture rate = 0.953031
#     class # 1 capture rate = 0.971147
# TRAIN: Batch: 0.2025084040987701 Loss: 0.013337603
# accuracy = 0.965052
# mean IU  = 0.837926
#     class # 0 capture rate = 0.963127
#     class # 1 capture rate = 0.984848
# TRAIN: Batch: 0.20385846012609524 Loss: 0.012047964
# accuracy = 0.966592
# mean IU  = 0.812032
#     class # 0 capture rate = 0.965791
#     class # 1 capture rate = 0.977884
# TRAIN: Batch: 0.20520851615342037 Loss: 0.011269053
# accuracy = 0.971233
# mean IU  = 0.867345
#     class # 0 capture rate = 0.969777
#     class # 1 capture rate = 0.984968
# TRAIN: Batch: 0.2065585721807455 Loss: 0.012286045
# accuracy = 0.967226
# mean IU  = 0.840304
#     class # 0 capture rate = 0.965348
#     class # 1 capture rate = 0.987759
# TRAIN: Batch: 0.20790862820807063 Loss: 0.0136383
# accuracy = 0.967451
# mean IU  = 0.860915
#     class # 0 capture rate = 0.966435
#     class # 1 capture rate = 0.976163
# TRAIN: Batch: 0.20925868423539576 Loss: 0.013620335
# accuracy = 0.967106
# mean IU  = 0.839831
#     class # 0 capture rate = 0.966094
#     class # 1 capture rate = 0.978060
# TRAIN: Batch: 0.2106087402627209 Loss: 0.017273933
# accuracy = 0.953987
# mean IU  = 0.826215
#     class # 0 capture rate = 0.950258
#     class # 1 capture rate = 0.983761
# TRAIN: Batch: 0.21195879629004605 Loss: 0.01612762
# accuracy = 0.962002
# mean IU  = 0.849836
#     class # 0 capture rate = 0.959751
#     class # 1 capture rate = 0.979891
# TRAIN: Batch: 0.21330885231737118 Loss: 0.016632553
# accuracy = 0.954824
# mean IU  = 0.825495
#     class # 0 capture rate = 0.951434
#     class # 1 capture rate = 0.982813
# TRAIN: Batch: 0.2146589083446963 Loss: 0.01775514
# accuracy = 0.959190
# mean IU  = 0.843532
#     class # 0 capture rate = 0.957173
#     class # 1 capture rate = 0.974719
# TRAIN: Batch: 0.21600896437202144 Loss: 0.015304138
# accuracy = 0.956085
# mean IU  = 0.796168
#     class # 0 capture rate = 0.953656
#     class # 1 capture rate = 0.984293
# TRAIN: Batch: 0.21735902039934657 Loss: 0.016629027
# accuracy = 0.956527
# mean IU  = 0.825925
#     class # 0 capture rate = 0.953999
#     class # 1 capture rate = 0.978353
# TRAIN: Batch: 0.2187090764266717 Loss: 0.016627427
# accuracy = 0.962125
# mean IU  = 0.842078
#     class # 0 capture rate = 0.960607
#     class # 1 capture rate = 0.975350
# TRAIN: Batch: 0.22005913245399683 Loss: 0.015227842
# accuracy = 0.962416
# mean IU  = 0.820119
#     class # 0 capture rate = 0.962381
#     class # 1 capture rate = 0.962800
# TRAIN: Batch: 0.22140918848132196 Loss: 0.024505492
# accuracy = 0.946635
# mean IU  = 0.830858
#     class # 0 capture rate = 0.941841
#     class # 1 capture rate = 0.975285
# TRAIN: Batch: 0.22275924450864712 Loss: 0.018050412
# accuracy = 0.954109
# mean IU  = 0.818435
#     class # 0 capture rate = 0.951452
#     class # 1 capture rate = 0.977117
# TRAIN: Batch: 0.22410930053597225 Loss: 0.017361503
# accuracy = 0.959481
# mean IU  = 0.853905
#     class # 0 capture rate = 0.955999
#     class # 1 capture rate = 0.983565
# TRAIN: Batch: 0.22545935656329738 Loss: 0.017167225
# accuracy = 0.956266
# mean IU  = 0.845954
#     class # 0 capture rate = 0.952770
#     class # 1 capture rate = 0.980015
# TRAIN: Batch: 0.2268094125906225 Loss: 0.017608237
# accuracy = 0.958523
# mean IU  = 0.822994
#     class # 0 capture rate = 0.957671
#     class # 1 capture rate = 0.966514
# TRAIN: Batch: 0.22815946861794764 Loss: 0.012554266
# accuracy = 0.964637
# mean IU  = 0.824590
#     class # 0 capture rate = 0.963491
#     class # 1 capture rate = 0.977901
# TRAIN: Batch: 0.22950952464527277 Loss: 0.013866457
# accuracy = 0.962217
# mean IU  = 0.812614
#     class # 0 capture rate = 0.960812
#     class # 1 capture rate = 0.979061
# TRAIN: Batch: 0.2308595806725979 Loss: 0.017472556
# accuracy = 0.949265
# mean IU  = 0.783545
#     class # 0 capture rate = 0.947309
#     class # 1 capture rate = 0.969989
# TRAIN: Batch: 0.23220963669992303 Loss: 0.02694406
# accuracy = 0.930728
# mean IU  = 0.793072
#     class # 0 capture rate = 0.923837
#     class # 1 capture rate = 0.972217
# TRAIN: Batch: 0.2335596927272482 Loss: 0.015322787
# accuracy = 0.959339
# mean IU  = 0.819502
#     class # 0 capture rate = 0.957217
#     class # 1 capture rate = 0.980911
# TRAIN: Batch: 0.23490974875457332 Loss: 0.01394292
# accuracy = 0.966864
# mean IU  = 0.830680
#     class # 0 capture rate = 0.966631
#     class # 1 capture rate = 0.969594
# TRAIN: Batch: 0.23625980478189845 Loss: 0.016026322
# accuracy = 0.957276
# mean IU  = 0.841395
#     class # 0 capture rate = 0.954059
#     class # 1 capture rate = 0.981226
# TRAIN: Batch: 0.23760986080922358 Loss: 0.0135976765
# accuracy = 0.967039
# mean IU  = 0.832670
#     class # 0 capture rate = 0.966092
#     class # 1 capture rate = 0.978066
# TRAIN: Batch: 0.2389599168365487 Loss: 0.018657025
# accuracy = 0.956142
# mean IU  = 0.815942
#     class # 0 capture rate = 0.954353
#     class # 1 capture rate = 0.973007
# TRAIN: Batch: 0.24030997286387384 Loss: 0.017703902
# accuracy = 0.958754
# mean IU  = 0.812010
#     class # 0 capture rate = 0.958526
#     class # 1 capture rate = 0.961149
# TRAIN: Batch: 0.24166002889119897 Loss: 0.016479092
# accuracy = 0.957860
# mean IU  = 0.827013
#     class # 0 capture rate = 0.955343
#     class # 1 capture rate = 0.980345
# TRAIN: Batch: 0.2430100849185241 Loss: 0.014674997
# accuracy = 0.968278
# mean IU  = 0.842840
#     class # 0 capture rate = 0.968496
#     class # 1 capture rate = 0.965916
# TRAIN: Batch: 0.24436014094584926 Loss: 0.02581529
# accuracy = 0.934941
# mean IU  = 0.793685
#     class # 0 capture rate = 0.929347
#     class # 1 capture rate = 0.972036
# TRAIN: Batch: 0.2457101969731744 Loss: 0.017131338
# accuracy = 0.950032
# mean IU  = 0.801011
#     class # 0 capture rate = 0.946500
#     class # 1 capture rate = 0.982720
# TRAIN: Batch: 0.24706025300049952 Loss: 0.015833776
# accuracy = 0.959926
# mean IU  = 0.833341
#     class # 0 capture rate = 0.958109
#     class # 1 capture rate = 0.976081
# TRAIN: Batch: 0.24841030902782466 Loss: 0.02013289
# accuracy = 0.948083
# mean IU  = 0.810244
#     class # 0 capture rate = 0.944847
#     class # 1 capture rate = 0.973564
# TRAIN: Batch: 0.24976036505514979 Loss: 0.015808996
# accuracy = 0.956679
# mean IU  = 0.827806
#     class # 0 capture rate = 0.953549
#     class # 1 capture rate = 0.983434
# TRAIN: Batch: 0.25111042108247494 Loss: 0.021870818
# accuracy = 0.948477
# mean IU  = 0.814184
#     class # 0 capture rate = 0.945598
#     class # 1 capture rate = 0.970366
# TRAIN: Batch: 0.2524604771098001 Loss: 0.014809254
# accuracy = 0.960234
# mean IU  = 0.829829
#     class # 0 capture rate = 0.958416
#     class # 1 capture rate = 0.977238
# TRAIN: Batch: 0.2538105331371252 Loss: 0.011642889
# accuracy = 0.969960
# mean IU  = 0.833884
#     class # 0 capture rate = 0.969912
#     class # 1 capture rate = 0.970588
# TRAIN: Batch: 0.25516058916445034 Loss: 0.015542174
# accuracy = 0.959539
# mean IU  = 0.812920
#     class # 0 capture rate = 0.957881
#     class # 1 capture rate = 0.977616
# TRAIN: Batch: 0.25651064519177547 Loss: 0.01810396
# accuracy = 0.953450
# mean IU  = 0.806954
#     class # 0 capture rate = 0.951086
#     class # 1 capture rate = 0.976031
# TRAIN: Batch: 0.2578607012191006 Loss: 0.014070037
# accuracy = 0.963592
# mean IU  = 0.836833
#     class # 0 capture rate = 0.963061
#     class # 1 capture rate = 0.968726
# TRAIN: Batch: 0.2592107572464257 Loss: 0.013616348
# accuracy = 0.959244
# mean IU  = 0.818924
#     class # 0 capture rate = 0.957046
#     class # 1 capture rate = 0.981669
# TRAIN: Batch: 0.26056081327375086 Loss: 0.016865442
# accuracy = 0.956975
# mean IU  = 0.808361
#     class # 0 capture rate = 0.955276
#     class # 1 capture rate = 0.974776
# TRAIN: Batch: 0.261910869301076 Loss: 0.015962612
# accuracy = 0.965651
# mean IU  = 0.852985
#     class # 0 capture rate = 0.964562
#     class # 1 capture rate = 0.975197
# TRAIN: Batch: 0.2632609253284011 Loss: 0.014981851
# accuracy = 0.965347
# mean IU  = 0.846793
#     class # 0 capture rate = 0.964250
#     class # 1 capture rate = 0.975567
# TRAIN: Batch: 0.26461098135572625 Loss: 0.012946209
# accuracy = 0.968259
# mean IU  = 0.867259
#     class # 0 capture rate = 0.965962
#     class # 1 capture rate = 0.987299
# TRAIN: Batch: 0.2659610373830514 Loss: 0.01237298
# accuracy = 0.965414
# mean IU  = 0.846814
#     class # 0 capture rate = 0.963811
#     class # 1 capture rate = 0.980462
# TRAIN: Batch: 0.2673110934103765 Loss: 0.015996996
# accuracy = 0.959724
# mean IU  = 0.826489
#     class # 0 capture rate = 0.958079
#     class # 1 capture rate = 0.975359
# TRAIN: Batch: 0.26866114943770164 Loss: 0.014461148
# accuracy = 0.961319
# mean IU  = 0.828880
#     class # 0 capture rate = 0.959175
#     class # 1 capture rate = 0.982479
# TRAIN: Batch: 0.27001120546502677 Loss: 0.015576979
# accuracy = 0.956210
# mean IU  = 0.822653
#     class # 0 capture rate = 0.953218
#     class # 1 capture rate = 0.982834
# TRAIN: Batch: 0.27136126149235196 Loss: 0.01840051
# accuracy = 0.958031
# mean IU  = 0.820614
#     class # 0 capture rate = 0.956853
#     class # 1 capture rate = 0.969223
# TRAIN: Batch: 0.2727113175196771 Loss: 0.014971644
# accuracy = 0.963099
# mean IU  = 0.840687
#     class # 0 capture rate = 0.963112
#     class # 1 capture rate = 0.962981
# TRAIN: Batch: 0.2740613735470022 Loss: 0.015710374
# accuracy = 0.963172
# mean IU  = 0.824422
#     class # 0 capture rate = 0.962281
#     class # 1 capture rate = 0.972910
# TRAIN: Batch: 0.27541142957432735 Loss: 0.015475157
# accuracy = 0.958638
# mean IU  = 0.832845
#     class # 0 capture rate = 0.955491
#     class # 1 capture rate = 0.985859
# TRAIN: Batch: 0.2767614856016525 Loss: 0.016782006
# accuracy = 0.957454
# mean IU  = 0.823065
#     class # 0 capture rate = 0.955511
#     class # 1 capture rate = 0.975223
# TRAIN: Batch: 0.2781115416289776 Loss: 0.017164866
# accuracy = 0.953679
# mean IU  = 0.796273
#     class # 0 capture rate = 0.951793
#     class # 1 capture rate = 0.973789
# TRAIN: Batch: 0.27946159765630274 Loss: 0.012653509
# accuracy = 0.969986
# mean IU  = 0.863764
#     class # 0 capture rate = 0.968519
#     class # 1 capture rate = 0.983635
# TRAIN: Batch: 0.28081165368362787 Loss: 0.01409295
# accuracy = 0.964858
# mean IU  = 0.841102
#     class # 0 capture rate = 0.963187
#     class # 1 capture rate = 0.981252
# TRAIN: Batch: 0.282161709710953 Loss: 0.016747551
# accuracy = 0.956824
# mean IU  = 0.848108
#     class # 0 capture rate = 0.952912
#     class # 1 capture rate = 0.983305
# TRAIN: Batch: 0.28351176573827813 Loss: 0.013689814
# accuracy = 0.965040
# mean IU  = 0.836731
#     class # 0 capture rate = 0.963282
#     class # 1 capture rate = 0.983301
# TRAIN: Batch: 0.28486182176560326 Loss: 0.018388474
# accuracy = 0.950156
# mean IU  = 0.823389
#     class # 0 capture rate = 0.945573
#     class # 1 capture rate = 0.983733
# TRAIN: Batch: 0.2862118777929284 Loss: 0.016602667
# accuracy = 0.960776
# mean IU  = 0.815969
#     class # 0 capture rate = 0.960572
#     class # 1 capture rate = 0.962984
# TRAIN: Batch: 0.2875619338202535 Loss: 0.019073207
# accuracy = 0.955351
# mean IU  = 0.820167
#     class # 0 capture rate = 0.953297
#     class # 1 capture rate = 0.973432
# TRAIN: Batch: 0.28891198984757865 Loss: 0.011266386
# accuracy = 0.970506
# mean IU  = 0.860229
#     class # 0 capture rate = 0.968815
#     class # 1 capture rate = 0.987389
# TRAIN: Batch: 0.2902620458749038 Loss: 0.012945342
# accuracy = 0.968623
# mean IU  = 0.835441
#     class # 0 capture rate = 0.968126
#     class # 1 capture rate = 0.974587
# TRAIN: Batch: 0.2916121019022289 Loss: 0.01231846
# accuracy = 0.967059
# mean IU  = 0.861343
#     class # 0 capture rate = 0.964734
#     class # 1 capture rate = 0.986793
# TRAIN: Batch: 0.2929621579295541 Loss: 0.02430612
# accuracy = 0.944634
# mean IU  = 0.807436
#     class # 0 capture rate = 0.941196
#     class # 1 capture rate = 0.969864
# TRAIN: Batch: 0.29431221395687923 Loss: 0.012342459
# accuracy = 0.965658
# mean IU  = 0.841618
#     class # 0 capture rate = 0.963813
#     class # 1 capture rate = 0.984282
# TRAIN: Batch: 0.29566226998420436 Loss: 0.018690804
# accuracy = 0.960083
# mean IU  = 0.831085
#     class # 0 capture rate = 0.960125
#     class # 1 capture rate = 0.959707
# TRAIN: Batch: 0.2970123260115295 Loss: 0.021278005
# accuracy = 0.943166
# mean IU  = 0.807788
#     class # 0 capture rate = 0.937904
#     class # 1 capture rate = 0.980586
# TRAIN: Batch: 0.2983623820388546 Loss: 0.013082194
# accuracy = 0.964979
# mean IU  = 0.855264
#     class # 0 capture rate = 0.963347
#     class # 1 capture rate = 0.978578
# TRAIN: Batch: 0.29971243806617975 Loss: 0.015244682
# accuracy = 0.961324
# mean IU  = 0.838596
#     class # 0 capture rate = 0.959313
#     class # 1 capture rate = 0.979102
# TRAIN: Batch: 0.3010624940935049 Loss: 0.017587917
# accuracy = 0.961783
# mean IU  = 0.846958
#     class # 0 capture rate = 0.960410
#     class # 1 capture rate = 0.972895
# TRAIN: Batch: 0.30241255012083 Loss: 0.0125710815
# accuracy = 0.967914
# mean IU  = 0.871218
#     class # 0 capture rate = 0.965561
#     class # 1 capture rate = 0.986129
# TRAIN: Batch: 0.30376260614815515 Loss: 0.024119738
# accuracy = 0.940964
# mean IU  = 0.792994
#     class # 0 capture rate = 0.937678
#     class # 1 capture rate = 0.966340
# TRAIN: Batch: 0.3051126621754803 Loss: 0.016726688
# accuracy = 0.959576
# mean IU  = 0.829009
#     class # 0 capture rate = 0.957944
#     class # 1 capture rate = 0.974589
# TRAIN: Batch: 0.3064627182028054 Loss: 0.0179393
# accuracy = 0.954763
# mean IU  = 0.826430
#     class # 0 capture rate = 0.953000
#     class # 1 capture rate = 0.968915
# TRAIN: Batch: 0.30781277423013054 Loss: 0.014626453
# accuracy = 0.965884
# mean IU  = 0.836911
#     class # 0 capture rate = 0.964995
#     class # 1 capture rate = 0.975319
# TRAIN: Batch: 0.30916283025745567 Loss: 0.017764837
# accuracy = 0.953088
# mean IU  = 0.813999
#     class # 0 capture rate = 0.950807
#     class # 1 capture rate = 0.973063
# TRAIN: Batch: 0.3105128862847808 Loss: 0.015063778
# accuracy = 0.959973
# mean IU  = 0.837138
#     class # 0 capture rate = 0.957101
#     class # 1 capture rate = 0.984727
# TRAIN: Batch: 0.31186294231210593 Loss: 0.011708019
# accuracy = 0.966519
# mean IU  = 0.855763
#     class # 0 capture rate = 0.964117
#     class # 1 capture rate = 0.987908
# TRAIN: Batch: 0.31321299833943106 Loss: 0.016513774
# accuracy = 0.953447
# mean IU  = 0.815046
#     class # 0 capture rate = 0.950507
#     class # 1 capture rate = 0.979376
# TRAIN: Batch: 0.31456305436675625 Loss: 0.013029881
# accuracy = 0.968108
# mean IU  = 0.861401
#     class # 0 capture rate = 0.966268
#     class # 1 capture rate = 0.984379
# TRAIN: Batch: 0.3159131103940814 Loss: 0.015275702
# accuracy = 0.964939
# mean IU  = 0.845837
#     class # 0 capture rate = 0.964044
#     class # 1 capture rate = 0.973217
# TRAIN: Batch: 0.3172631664214065 Loss: 0.018273849
# accuracy = 0.958546
# mean IU  = 0.819309
#     class # 0 capture rate = 0.958082
#     class # 1 capture rate = 0.963060
# TRAIN: Batch: 0.31861322244873164 Loss: 0.01668943
# accuracy = 0.959293
# mean IU  = 0.829676
#     class # 0 capture rate = 0.957457
#     class # 1 capture rate = 0.975927
# TRAIN: Batch: 0.31996327847605677 Loss: 0.01625838
# accuracy = 0.961059
# mean IU  = 0.858761
#     class # 0 capture rate = 0.957622
#     class # 1 capture rate = 0.984767
# TRAIN: Batch: 0.3213133345033819 Loss: 0.011613891
# accuracy = 0.969259
# mean IU  = 0.839769
#     class # 0 capture rate = 0.968332
#     class # 1 capture rate = 0.980238
# TRAIN: Batch: 0.32266339053070703 Loss: 0.0137316035
# accuracy = 0.968940
# mean IU  = 0.876357
#     class # 0 capture rate = 0.967347
#     class # 1 capture rate = 0.980893
# TRAIN: Batch: 0.32401344655803216 Loss: 0.013077279
# accuracy = 0.965034
# mean IU  = 0.853234
#     class # 0 capture rate = 0.962302
#     class # 1 capture rate = 0.988682
# TRAIN: Batch: 0.3253635025853573 Loss: 0.019334828
# accuracy = 0.950219
# mean IU  = 0.810396
#     class # 0 capture rate = 0.947875
#     class # 1 capture rate = 0.969718
# TRAIN: Batch: 0.3267135586126824 Loss: 0.021104736
# accuracy = 0.944233
# mean IU  = 0.808057
#     class # 0 capture rate = 0.940068
#     class # 1 capture rate = 0.974416
# TRAIN: Batch: 0.32806361464000755 Loss: 0.020841666
# accuracy = 0.945586
# mean IU  = 0.816183
#     class # 0 capture rate = 0.940553
#     class # 1 capture rate = 0.980445
# TRAIN: Batch: 0.3294136706673327 Loss: 0.014418508
# accuracy = 0.964930
# mean IU  = 0.861751
#     class # 0 capture rate = 0.962082
#     class # 1 capture rate = 0.986980
# TRAIN: Batch: 0.3307637266946578 Loss: 0.019508561
# accuracy = 0.954991
# mean IU  = 0.824370
#     class # 0 capture rate = 0.953220
#     class # 1 capture rate = 0.969642
# TRAIN: Batch: 0.33211378272198294 Loss: 0.015841717
# accuracy = 0.953819
# mean IU  = 0.803862
#     class # 0 capture rate = 0.951143
#     class # 1 capture rate = 0.980630
# TRAIN: Batch: 0.3334638387493081 Loss: 0.016582327
# accuracy = 0.953425
# mean IU  = 0.823744
#     class # 0 capture rate = 0.949889
#     class # 1 capture rate = 0.981882
# TRAIN: Batch: 0.3348138947766332 Loss: 0.014857603
# accuracy = 0.961582
# mean IU  = 0.831017
#     class # 0 capture rate = 0.959672
#     class # 1 capture rate = 0.980120
# TRAIN: Batch: 0.3361639508039584 Loss: 0.015838789
# accuracy = 0.966744
# mean IU  = 0.851817
#     class # 0 capture rate = 0.966597
#     class # 1 capture rate = 0.968096
# ...
# TRAIN: Batch: 0.001350056027325134 Loss: 0.014616504
# accuracy = 0.961348
# mean IU  = 0.846271
#     class # 0 capture rate = 0.957968
#     class # 1 capture rate = 0.989011
# TRAIN: Batch: 0.002700112054650268 Loss: 0.013181383
# accuracy = 0.963595
# mean IU  = 0.844901
#     class # 0 capture rate = 0.960683
#     class # 1 capture rate = 0.989941
# TRAIN: Batch: 0.004050168081975402 Loss: 0.0185151
# accuracy = 0.958261
# mean IU  = 0.827016
#     class # 0 capture rate = 0.957248
#     class # 1 capture rate = 0.967297
# TRAIN: Batch: 0.005400224109300536 Loss: 0.017305974
# accuracy = 0.957093
# mean IU  = 0.835994
#     class # 0 capture rate = 0.953965
#     class # 1 capture rate = 0.981767
# TRAIN: Batch: 0.00675028013662567 Loss: 0.016974604
# accuracy = 0.963353
# mean IU  = 0.822652
#     class # 0 capture rate = 0.963654
#     class # 1 capture rate = 0.960024
# TRAIN: Batch: 0.008100336163950804 Loss: 0.014034542
# accuracy = 0.959271
# mean IU  = 0.831346
#     class # 0 capture rate = 0.956210
#     class # 1 capture rate = 0.986816
# TRAIN: Batch: 0.009450392191275938 Loss: 0.013741407
# accuracy = 0.964302
# mean IU  = 0.839477
#     class # 0 capture rate = 0.963734
#     class # 1 capture rate = 0.969792
# TRAIN: Batch: 0.010800448218601072 Loss: 0.013259709
# accuracy = 0.965201
# mean IU  = 0.836044
#     class # 0 capture rate = 0.963270
#     class # 1 capture rate = 0.985601
# TRAIN: Batch: 0.012150504245926206 Loss: 0.0153860655
# accuracy = 0.958702
# mean IU  = 0.820379
#     class # 0 capture rate = 0.955886
#     class # 1 capture rate = 0.986656
# TRAIN: Batch: 0.01350056027325134 Loss: 0.01964914
# accuracy = 0.952305
# mean IU  = 0.794073
#     class # 0 capture rate = 0.951105
#     class # 1 capture rate = 0.964752
# TRAIN: Batch: 0.014850616300576474 Loss: 0.015127298
# accuracy = 0.962640
# mean IU  = 0.839976
#     class # 0 capture rate = 0.960849
#     class # 1 capture rate = 0.978986
# TRAIN: Batch: 0.016200672327901608 Loss: 0.017318975
# accuracy = 0.959387
# mean IU  = 0.820595
#     class # 0 capture rate = 0.958597
#     class # 1 capture rate = 0.967217
# TRAIN: Batch: 0.017550728355226742 Loss: 0.017652819
# accuracy = 0.959149
# mean IU  = 0.830668
#     class # 0 capture rate = 0.957309
#     class # 1 capture rate = 0.975551
# TRAIN: Batch: 0.018900784382551876 Loss: 0.017727986
# accuracy = 0.951138
# mean IU  = 0.811407
#     class # 0 capture rate = 0.947928
#     class # 1 capture rate = 0.978560
# TRAIN: Batch: 0.02025084040987701 Loss: 0.015636329
# accuracy = 0.959945
# mean IU  = 0.828024
#     class # 0 capture rate = 0.957850
#     class # 1 capture rate = 0.979795
# TRAIN: Batch: 0.021600896437202144 Loss: 0.014298774
# accuracy = 0.962339
# mean IU  = 0.845356
#     class # 0 capture rate = 0.959885
#     class # 1 capture rate = 0.983252
# TRAIN: Batch: 0.022950952464527278 Loss: 0.017134964
# accuracy = 0.953826
# mean IU  = 0.836705
#     class # 0 capture rate = 0.950271
#     class # 1 capture rate = 0.978711
# TRAIN: Batch: 0.024301008491852412 Loss: 0.014827527
# accuracy = 0.959922
# mean IU  = 0.830423
#     class # 0 capture rate = 0.957250
#     class # 1 capture rate = 0.984696
# TRAIN: Batch: 0.025651064519177546 Loss: 0.019135859
# accuracy = 0.951475
# mean IU  = 0.830327
#     class # 0 capture rate = 0.947270
#     class # 1 capture rate = 0.980999
# TRAIN: Batch: 0.02700112054650268 Loss: 0.01850543
# accuracy = 0.954801
# mean IU  = 0.819111
#     class # 0 capture rate = 0.951903
#     class # 1 capture rate = 0.980345
# TRAIN: Batch: 0.028351176573827814 Loss: 0.012362423
# accuracy = 0.968930
# mean IU  = 0.861401
#     class # 0 capture rate = 0.967140
#     class # 1 capture rate = 0.985345
# TRAIN: Batch: 0.029701232601152948 Loss: 0.012909922
# accuracy = 0.960162
# mean IU  = 0.825773
#     class # 0 capture rate = 0.958108
#     class # 1 capture rate = 0.980253
# TRAIN: Batch: 0.031051288628478082 Loss: 0.019042008
# accuracy = 0.946157
# mean IU  = 0.812293
#     class # 0 capture rate = 0.940896
#     class # 1 capture rate = 0.985038
# TRAIN: Batch: 0.032401344655803216 Loss: 0.016010646
# accuracy = 0.959796
# mean IU  = 0.854742
#     class # 0 capture rate = 0.956471
#     class # 1 capture rate = 0.982792
# TRAIN: Batch: 0.033751400683128346 Loss: 0.012208881
# accuracy = 0.967961
# mean IU  = 0.843398
#     class # 0 capture rate = 0.966808
#     class # 1 capture rate = 0.980409
# TRAIN: Batch: 0.035101456710453484 Loss: 0.016279496
# accuracy = 0.961792
# mean IU  = 0.850908
#     class # 0 capture rate = 0.959080
#     class # 1 capture rate = 0.982989
# TRAIN: Batch: 0.036451512737778614 Loss: 0.019634057
# accuracy = 0.950446
# mean IU  = 0.816549
#     class # 0 capture rate = 0.947122
#     class # 1 capture rate = 0.976724
# TRAIN: Batch: 0.03780156876510375 Loss: 0.016286299
# accuracy = 0.959134
# mean IU  = 0.822726
#     class # 0 capture rate = 0.957610
#     class # 1 capture rate = 0.973897
# TRAIN: Batch: 0.03915162479242888 Loss: 0.013952866
# accuracy = 0.966924
# mean IU  = 0.873164
#     class # 0 capture rate = 0.964771
#     class # 1 capture rate = 0.982400
# TRAIN: Batch: 0.04050168081975402 Loss: 0.01588174
# accuracy = 0.957828
# mean IU  = 0.824879
#     class # 0 capture rate = 0.955663
#     class # 1 capture rate = 0.977536
# TRAIN: Batch: 0.04185173684707915 Loss: 0.015293218
# accuracy = 0.962656
# mean IU  = 0.846653
#     class # 0 capture rate = 0.960856
#     class # 1 capture rate = 0.977860
# TRAIN: Batch: 0.04320179287440429 Loss: 0.015449476
# accuracy = 0.962933
# mean IU  = 0.839579
#     class # 0 capture rate = 0.961569
#     class # 1 capture rate = 0.975524
# TRAIN: Batch: 0.04455184890172942 Loss: 0.013377431
# accuracy = 0.966881
# mean IU  = 0.854875
#     class # 0 capture rate = 0.964791
#     class # 1 capture rate = 0.985922
# TRAIN: Batch: 0.045901904929054556 Loss: 0.014574558
# accuracy = 0.962388
# mean IU  = 0.821130
#     class # 0 capture rate = 0.961598
#     class # 1 capture rate = 0.971053
# TRAIN: Batch: 0.047251960956379686 Loss: 0.013592732
# accuracy = 0.966034
# mean IU  = 0.860406
#     class # 0 capture rate = 0.963973
#     class # 1 capture rate = 0.982933
# TRAIN: Batch: 0.048602016983704824 Loss: 0.015384436
# accuracy = 0.964284
# mean IU  = 0.831111
#     class # 0 capture rate = 0.963122
#     class # 1 capture rate = 0.976658
# TRAIN: Batch: 0.049952073011029954 Loss: 0.020350223
# accuracy = 0.945926
# mean IU  = 0.824657
#     class # 0 capture rate = 0.939820
#     class # 1 capture rate = 0.984865
# TRAIN: Batch: 0.05130212903835509 Loss: 0.013228282
# accuracy = 0.968984
# mean IU  = 0.831068
#     class # 0 capture rate = 0.968860
#     class # 1 capture rate = 0.970559
# TRAIN: Batch: 0.05265218506568022 Loss: 0.019219557
# accuracy = 0.950625
# mean IU  = 0.822952
#     class # 0 capture rate = 0.947301
#     class # 1 capture rate = 0.975200
# TRAIN: Batch: 0.05400224109300536 Loss: 0.014034542
# accuracy = 0.962641
# mean IU  = 0.835804
#     class # 0 capture rate = 0.960763
#     class # 1 capture rate = 0.980630
# TRAIN: Batch: 0.05535229712033049 Loss: 0.017212156
# accuracy = 0.952809
# mean IU  = 0.819684
#     class # 0 capture rate = 0.948971
#     class # 1 capture rate = 0.984587
# TRAIN: Batch: 0.05670235314765563 Loss: 0.013957122
# accuracy = 0.966440
# mean IU  = 0.847811
#     class # 0 capture rate = 0.964962
#     class # 1 capture rate = 0.980719
# TRAIN: Batch: 0.05805240917498076 Loss: 0.015686397
# accuracy = 0.965818
# mean IU  = 0.862526
#     class # 0 capture rate = 0.964331
#     class # 1 capture rate = 0.977504
# TRAIN: Batch: 0.059402465202305896 Loss: 0.010712996
# accuracy = 0.973110
# mean IU  = 0.880708
#     class # 0 capture rate = 0.971007
#     class # 1 capture rate = 0.991453
# TRAIN: Batch: 0.060752521229631026 Loss: 0.020495798
# accuracy = 0.950403
# mean IU  = 0.803125
#     class # 0 capture rate = 0.947677
#     class # 1 capture rate = 0.975148
# TRAIN: Batch: 0.062102577256956164 Loss: 0.01935605
# accuracy = 0.947381
# mean IU  = 0.798204
#     class # 0 capture rate = 0.943568
#     class # 1 capture rate = 0.981037
# TRAIN: Batch: 0.0634526332842813 Loss: 0.014747368
# accuracy = 0.959902
# mean IU  = 0.836938
#     class # 0 capture rate = 0.957413
#     class # 1 capture rate = 0.981273
# TRAIN: Batch: 0.06480268931160643 Loss: 0.016393082
# accuracy = 0.953365
# mean IU  = 0.806818
#     class # 0 capture rate = 0.950217
#     class # 1 capture rate = 0.983658
# TRAIN: Batch: 0.06615274533893156 Loss: 0.01644905
# accuracy = 0.959671
# mean IU  = 0.832549
#     class # 0 capture rate = 0.958112
#     class # 1 capture rate = 0.973488
# TRAIN: Batch: 0.06750280136625669 Loss: 0.015780607
# accuracy = 0.959023
# mean IU  = 0.823874
#     class # 0 capture rate = 0.957115
#     class # 1 capture rate = 0.977284
# TRAIN: Batch: 0.06885285739358184 Loss: 0.021118581
# accuracy = 0.948442
# mean IU  = 0.790143
#     class # 0 capture rate = 0.945981
#     class # 1 capture rate = 0.972434
# TRAIN: Batch: 0.07020291342090697 Loss: 0.01806517
# accuracy = 0.949077
# mean IU  = 0.811719
#     class # 0 capture rate = 0.945236
#     class # 1 capture rate = 0.979925
# TRAIN: Batch: 0.0715529694482321 Loss: 0.017475422
# accuracy = 0.960396
# mean IU  = 0.835361
#     class # 0 capture rate = 0.959128
#     class # 1 capture rate = 0.971545
# TRAIN: Batch: 0.07290302547555723 Loss: 0.013851767
# accuracy = 0.960733
# mean IU  = 0.846604
#     class # 0 capture rate = 0.957866
#     class # 1 capture rate = 0.983442
# TRAIN: Batch: 0.07425308150288237 Loss: 0.016012589
# accuracy = 0.959678
# mean IU  = 0.785804
#     class # 0 capture rate = 0.959334
#     class # 1 capture rate = 0.964482
# TRAIN: Batch: 0.0756031375302075 Loss: 0.014748407
# accuracy = 0.969444
# mean IU  = 0.873441
#     class # 0 capture rate = 0.967506
#     class # 1 capture rate = 0.985002
# TRAIN: Batch: 0.07695319355753263 Loss: 0.015289402
# accuracy = 0.957137
# mean IU  = 0.817205
#     class # 0 capture rate = 0.954346
#     class # 1 capture rate = 0.984281
# TRAIN: Batch: 0.07830324958485776 Loss: 0.016039457
# accuracy = 0.965226
# mean IU  = 0.858736
#     class # 0 capture rate = 0.963204
#     class # 1 capture rate = 0.981580
# TRAIN: Batch: 0.07965330561218291 Loss: 0.016988073
# accuracy = 0.952024
# mean IU  = 0.810619
#     class # 0 capture rate = 0.949147
#     class # 1 capture rate = 0.977426
# TRAIN: Batch: 0.08100336163950804 Loss: 0.019907322
# accuracy = 0.943432
# mean IU  = 0.806297
#     class # 0 capture rate = 0.938250
#     class # 1 capture rate = 0.981182
# TRAIN: Batch: 0.08235341766683317 Loss: 0.01692776
# accuracy = 0.955487
# mean IU  = 0.830485
#     class # 0 capture rate = 0.952469
#     class # 1 capture rate = 0.979467
# TRAIN: Batch: 0.0837034736941583 Loss: 0.020344133
# accuracy = 0.955283
# mean IU  = 0.827124
#     class # 0 capture rate = 0.954020
#     class # 1 capture rate = 0.965464
# TRAIN: Batch: 0.08505352972148345 Loss: 0.0121527
# accuracy = 0.971940
# mean IU  = 0.876231
#     class # 0 capture rate = 0.970453
#     class # 1 capture rate = 0.984859
# TRAIN: Batch: 0.08640358574880858 Loss: 0.014453821
# accuracy = 0.959894
# mean IU  = 0.809546
#     class # 0 capture rate = 0.958447
#     class # 1 capture rate = 0.976385
# TRAIN: Batch: 0.0877536417761337 Loss: 0.018981665
# accuracy = 0.953358
# mean IU  = 0.827552
#     class # 0 capture rate = 0.950141
#     class # 1 capture rate = 0.978003
# TRAIN: Batch: 0.08910369780345884 Loss: 0.013270587
# accuracy = 0.965497
# mean IU  = 0.848348
#     class # 0 capture rate = 0.963905
#     class # 1 capture rate = 0.980225
# TRAIN: Batch: 0.09045375383078398 Loss: 0.012507093
# accuracy = 0.966915
# mean IU  = 0.843402
#     class # 0 capture rate = 0.965129
#     class # 1 capture rate = 0.985511
# TRAIN: Batch: 0.09180380985810911 Loss: 0.015037867
# accuracy = 0.961682
# mean IU  = 0.835941
#     class # 0 capture rate = 0.960295
#     class # 1 capture rate = 0.974410
# TRAIN: Batch: 0.09315386588543424 Loss: 0.017429072
# accuracy = 0.958774
# mean IU  = 0.825782
#     class # 0 capture rate = 0.956931
#     class # 1 capture rate = 0.975885
# TRAIN: Batch: 0.09450392191275937 Loss: 0.01724732
# accuracy = 0.959371
# mean IU  = 0.836372
#     class # 0 capture rate = 0.957419
#     class # 1 capture rate = 0.975823
# TRAIN: Batch: 0.09585397794008452 Loss: 0.013388974
# accuracy = 0.962399
# mean IU  = 0.832276
#     class # 0 capture rate = 0.960086
#     class # 1 capture rate = 0.985337
# TRAIN: Batch: 0.09720403396740965 Loss: 0.01713835
# accuracy = 0.959058
# mean IU  = 0.820875
#     class # 0 capture rate = 0.957591
#     class # 1 capture rate = 0.973503
# TRAIN: Batch: 0.09855408999473478 Loss: 0.012377505
# accuracy = 0.969248
# mean IU  = 0.853876
#     class # 0 capture rate = 0.967855
#     class # 1 capture rate = 0.983388
# TRAIN: Batch: 0.09990414602205991 Loss: 0.015750566
# accuracy = 0.962168
# mean IU  = 0.847780
#     class # 0 capture rate = 0.960704
#     class # 1 capture rate = 0.974090
# TRAIN: Batch: 0.10125420204938505 Loss: 0.016103875
# accuracy = 0.957679
# mean IU  = 0.822358
#     class # 0 capture rate = 0.955358
#     class # 1 capture rate = 0.979324
# TRAIN: Batch: 0.10260425807671018 Loss: 0.01760615
# accuracy = 0.954325
# mean IU  = 0.810770
#     class # 0 capture rate = 0.951714
#     class # 1 capture rate = 0.979039
# TRAIN: Batch: 0.10395431410403531 Loss: 0.0113903405
# accuracy = 0.969499
# mean IU  = 0.864588
#     class # 0 capture rate = 0.968459
#     class # 1 capture rate = 0.978822
# TRAIN: Batch: 0.10530437013136044 Loss: 0.012426773
# accuracy = 0.972959
# mean IU  = 0.876635
#     class # 0 capture rate = 0.972796
#     class # 1 capture rate = 0.974421
# TRAIN: Batch: 0.10665442615868559 Loss: 0.011428781
# accuracy = 0.971474
# mean IU  = 0.849208
#     class # 0 capture rate = 0.970948
#     class # 1 capture rate = 0.977633
# TRAIN: Batch: 0.10800448218601072 Loss: 0.015487219
# accuracy = 0.957054
# mean IU  = 0.809812
#     class # 0 capture rate = 0.955087
#     class # 1 capture rate = 0.977475
# TRAIN: Batch: 0.10935453821333585 Loss: 0.020562012
# accuracy = 0.948637
# mean IU  = 0.778436
#     class # 0 capture rate = 0.947089
#     class # 1 capture rate = 0.965477
# TRAIN: Batch: 0.11070459424066098 Loss: 0.012859869
# accuracy = 0.970794
# mean IU  = 0.864978
#     class # 0 capture rate = 0.969292
#     class # 1 capture rate = 0.985094
# TRAIN: Batch: 0.11205465026798613 Loss: 0.015021679
# accuracy = 0.958368
# mean IU  = 0.826522
#     class # 0 capture rate = 0.956158
#     class # 1 capture rate = 0.978513
# TRAIN: Batch: 0.11340470629531126 Loss: 0.020268848
# accuracy = 0.954849
# mean IU  = 0.833779
#     class # 0 capture rate = 0.952542
#     class # 1 capture rate = 0.971988
# TRAIN: Batch: 0.11475476232263639 Loss: 0.020102393
# accuracy = 0.949332
# mean IU  = 0.829497
#     class # 0 capture rate = 0.945123
#     class # 1 capture rate = 0.977142
# TRAIN: Batch: 0.11610481834996152 Loss: 0.020604923
# accuracy = 0.946016
# mean IU  = 0.804304
#     class # 0 capture rate = 0.941851
#     class # 1 capture rate = 0.979194
# TRAIN: Batch: 0.11745487437728666 Loss: 0.013605112
# accuracy = 0.966095
# mean IU  = 0.849754
#     class # 0 capture rate = 0.964828
#     class # 1 capture rate = 0.977873
# TRAIN: Batch: 0.11880493040461179 Loss: 0.02306012
# accuracy = 0.950799
# mean IU  = 0.813684
#     class # 0 capture rate = 0.948871
#     class # 1 capture rate = 0.966495
# TRAIN: Batch: 0.12015498643193692 Loss: 0.020925809
# accuracy = 0.945160
# mean IU  = 0.783423
#     class # 0 capture rate = 0.942043
#     class # 1 capture rate = 0.974968
# TRAIN: Batch: 0.12150504245926205 Loss: 0.013597703
# accuracy = 0.961973
# mean IU  = 0.832755
#     class # 0 capture rate = 0.960242
#     class # 1 capture rate = 0.978679
# TRAIN: Batch: 0.1228550984865872 Loss: 0.0204774
# accuracy = 0.950583
# mean IU  = 0.823803
#     class # 0 capture rate = 0.946767
#     class # 1 capture rate = 0.978602
# TRAIN: Batch: 0.12420515451391233 Loss: 0.01568447
# accuracy = 0.958803
# mean IU  = 0.826416
#     class # 0 capture rate = 0.955905
#     class # 1 capture rate = 0.985866
# TRAIN: Batch: 0.12555521054123747 Loss: 0.015002454
# accuracy = 0.960676
# mean IU  = 0.813506
#     class # 0 capture rate = 0.959203
#     class # 1 capture rate = 0.977252
# TRAIN: Batch: 0.1269052665685626 Loss: 0.016586898
# accuracy = 0.953336
# mean IU  = 0.802563
#     class # 0 capture rate = 0.950681
#     class # 1 capture rate = 0.979866
